# %% [markdown]
# #idle을 이용한 파이썬 코딩
# ![abc.png](attachment:abc.png)

# %%
katok=[]
    
a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==1:
    b=input("추가할 데이터-->")
    katok.append(b)

    print(katok)


a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==1:
    b=input("추가할 데이터-->")
    katok.append(b)

    print(katok)

a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==1:
    b=input("추가할 데이터-->")
    katok.append(b)

    print(katok)
 
a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==2:
    b=input("삭제할 순서-->")
    del(katok[1])

    print(katok)

a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==2:
    b=input("삭제할 순서-->")
    print("삭제할 데이터가 존재하지 않습니다")
    
a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))

# %% [markdown]
# ![abc.png](attachment:abc.png)

# %% [markdown]
# ![%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-10-02%20233358.png](attachment:%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-10-02%20233358.png)

# %%
katok=[]
    
a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==1:
    b=input("추가할 데이터-->")
    katok.append(b)

    print(katok)


a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==1:
    b=input("추가할 데이터-->")
    katok.append(b)

    print(katok)

a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==1:
    b=input("추가할 데이터-->")
    katok.append(b)
    katok.sort()
    print(katok)
 
a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==2:
    b=input("삭제할 순서-->")
    del(katok[1])

    print(katok)

a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
if a==2:
    b=input("삭제할 순서-->")
    print("삭제할 데이터가 존재하지 않습니다")
    
a=int(input("선택하세요(1:추가, 2:삭제,3:종료)-->"))
# Out:
# 선택하세요(1:추가, 2:삭제,3:종료)-->1
# 추가할 데이터-->('다현',200)
# ["('다현',200)"]
# 선택하세요(1:추가, 2:삭제,3:종료)-->1
# 추가할 데이터-->('정연',150)
# ["('다현',200)", "('정연',150)"]
# 선택하세요(1:추가, 2:삭제,3:종료)-->1
# 추가할 데이터-->('모모',170)
# ["('다현',200)", "('모모',170)", "('정연',150)"]
# 선택하세요(1:추가, 2:삭제,3:종료)-->2
# 삭제할 순서-->2
# ["('다현',200)", "('정연',150)"]
# 선택하세요(1:추가, 2:삭제,3:종료)-->2
# 삭제할 순서-->2
# 삭제할 데이터가 존재하지 않습니다
# 선택하세요(1:추가, 2:삭제,3:종료)-->2
